# %%
import pandas as pd

# %%
import requests

# %%
url = 'https://www.alphavantage.co/query?function=MARKET_STATUS&apikey=0L25ZR4JWE5MOC0T'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'endpoint': 'Global Market Open & Close Status', 'markets': [{'market_type': 'Equity', 'region': 'United States', 'primary_exchanges': 'NASDAQ, NYSE, AMEX, BATS', 'local_open': '09:30', 'local_close': '16:00', 'current_status': 'open', 'notes': ''}, {'market_type': 'Equity', 'region': 'Canada', 'primary_exchanges': 'Toronto, Toronto Ventures', 'local_open': '09:30', 'local_close': '16:00', 'current_status': 'open', 'notes': ''}, {'market_type': 'Equity', 'region': 'United Kingdom', 'primary_exchanges': 'London', 'local_open': '08:00', 'local_close': '16:30', 'current_status': 'closed', 'notes': ''}, {'market_type': 'Equity', 'region': 'Germany', 'primary_exchanges': 'XETRA, Berlin, Frankfurt, Munich, Stuttgart', 'local_open': '08:00', 'local_close': '20:00', 'current_status': 'open', 'notes': ''}, {'market_type': 'Equity', 'region': 'France', 'primary_exchanges': 'Paris', 'local_open': '09:00', 'local_close': '17:30', 'current_status': 'closed', 'notes': ''}, {'market_type': 'Equity
# ...

# %%
url_news = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&time_from=20120410T0130&time_to=20120510T0130&limit=200&sort=EARLIEST&apikey=0L25ZR4JWE5MOC0T'
r_news = requests.get(url_news)
data_news = r_news.json()

data_news
# Out:
# {'Information': 'No articles found. Please adjust the time range or refer to the API documentation https://www.alphavantage.co/documentation#newsapi and try again.'}

# %%
apple_df = pd.DataFrame(data_news)
apple_df
# Out:
#     items                         sentiment_score_definition  \
# 0     200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 1     200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 2     200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 3     200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 4     200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# ..    ...                                                ...
# 195   200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 196   200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 197   200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 198   200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
# 199   200  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                             relevance_score_definition  \
# 0    0 < x <= 1, with a higher score indicating hig...
# 1    0 < x <= 1, with a higher score indicating hig...
# 2    0 < x <= 1, with a higher score indicating hig...
# ...

# %%
# !pip install pandas-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 66.1 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
# example using time_series_daily_adjusted

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=IBM&outputsize=full&apikey=0L25ZR4JWE5MOC0T'
r = requests.get(url)
data = r.json()

data
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2023-03-06',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-03-06': {'1. open': '129.64',
#    '2. high': '130.86',
#    '3. low': '129.59',
#    '4. close': '130.19',
#    '5. adjusted close': '130.19',
#    '6. volume': '2982980',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-03-03': {'1. open': '129.35',
#    '2. high': '129.905',
#    '3. low': '128.77',
#    '4. close': '129.64',
#    '5. adjusted close': '129.64',
#    '6. volume': '2860286',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-03-02': {'1. open': '128.39',
#    '2. high': '129.22',
#    '3. low': '127.71',
#    '4. close': '128.93',
#    '5. adjusted close': '128.93',
#    '6. volume': '3340254',
#    '7. dividend amount': '0.0000',
# ...

# %%
data.index = pd.to_datetime(data.index, format='%Y-%m-%d')
# plotting the opening and closing value 
df[['open','close']].plot()

# %%
## Alpha vintage Example from analyticsindiamag.com

import pandas_datareader as pdr
ts = pdr.av.time_series.AVTimeSeriesReader('IBM', api_key='0L25ZR4JWE5MOC0T')
df = ts.read()
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
# plotting the opening and closing value 
df[['open','close']].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/project-ais/lib/python3.10/site-packages/pandas_datareader/av/__init__.py:72, in AlphaVantage._read_lines(self, out)
#      71 try:
# ---> 72     df = pd.DataFrame.from_dict(out[self.data_key], orient="index")
#      73 except KeyError:
#
# KeyError: 'Time Series (Daily)'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Cell In[22], line 5
#       3 import pandas_datareader as pdr
#       4 ts = pdr.av.time_series.AVTimeSeriesReader('IBM', api_key='0L25ZR4JWE5MOC0T')
# ----> 5 df = ts.read()
#       6 df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
#       7 # plotting the opening and closing value
#
# ...
